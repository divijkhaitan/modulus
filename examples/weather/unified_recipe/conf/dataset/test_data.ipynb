# %%
import xarray as xr
import zarr

# %%
ds = xr.open_zarr("/Datastorage/divij.khaitan_asp25/era5/era5_2023_jjas13level.zarr")
ds
# Out:
# <xarray.Dataset> Size: 179GB
# Dimensions:                       (time: 485, latitude: 721, longitude: 1440,
#                                    level: 13)
# Coordinates:
#   * latitude                      (latitude) float32 3kB 90.0 89.75 ... -90.0
#   * level                         (level) int64 104B 50 100 150 ... 850 925 1000
#   * longitude                     (longitude) float32 6kB 0.0 0.25 ... 359.8
#   * time                          (time) datetime64[ns] 4kB 2023-06-01 ... 20...
# Data variables: (12/21)
#     10m_u_component_of_wind       (time, latitude, longitude) float32 2GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     10m_v_component_of_wind       (time, latitude, longitude) float32 2GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     2m_temperature                (time, latitude, longitude) float32 2GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...
